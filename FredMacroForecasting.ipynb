# %%
import pandas as pd

# %%
from FredQD import FredQD

# %%
fqd = FredQD(Nfactor=None, vintage=None, maxfactor=8, standard_method=2, ic_method=2, start_date="1980-03-01")
# Out:
# https://files.stlouisfed.org/files/htdocs/fred-md/quarterly/current.csv

# %%
fqd.rawseries

# %%
fqd.forecast_recursive()

# %%
import matplotlib.pyplot as plt

# %%
series = fqd.rawseries['GDPC1']
series
# Out:
# 1959-03-01     3123.978
# 1959-06-01     3194.429
# 1959-09-01     3196.683
# 1959-12-01     3205.790
# 1960-03-01     3277.847
#                 ...
# 2020-12-01    18767.778
# 2021-03-01    19055.655
# 2021-06-01    19368.310
# 2021-09-01    19478.893
# 2021-12-01    19806.290
# Name: GDPC1, Length: 252, dtype: float64

# %%
# %matplotlib inline

# %%
series.plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
fqd.estimate_factors()
# Out:
# EM algorithm converged after 1 iterations

# %%
fqd.series_filled['GDPC1'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
fqd.series_filled['GDPC1'].plot(kind="hist", legend=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = fqd.series_filled.drop("GDPC1", axis=1)

# %%
data.corr()
# Out:
#                 PCECC96     PCDGx    PCESVx     PCNDx    GPDIC1      FPIx  \
# PCECC96        1.000000  0.805869  0.695206  0.615800  0.239961  0.557028
# PCDGx          0.805869  1.000000  0.253513  0.472936  0.282809  0.542987
# PCESVx         0.695206  0.253513  1.000000  0.314799  0.131097  0.348359
# PCNDx          0.615800  0.472936  0.314799  1.000000  0.312485  0.468926
# GPDIC1         0.239961  0.282809  0.131097  0.312485  1.000000  0.686809
# ...                 ...       ...       ...       ...       ...       ...
# CNCFx          0.014097  0.056568  0.038195  0.121640  0.062078 -0.063857
# S&P 500        0.319873  0.273417  0.198313  0.330815  0.152503  0.298296
# S&P: indust    0.320341  0.275081  0.193894  0.322136  0.136613  0.282470
# S&P div yield -0.297962 -0.255365 -0.190052 -0.251114 -0.072567 -0.206869
# S&P PE ratio   0.128041  0.162954  0.006535  0.152880 -0.025650 -0.002310
#
#                Y033RC1Q027SBEAx     PNFIx     PRFIx  A014RE1Q156NBEA  ...  \
# ...

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(15, 10))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(data.corr().abs(), vmin=0, vmax=1, annot=False)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('FRED-QD: Coreelation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
import pickle

# %%
fqd_p = pickle.load( open("fred_qd.pickle", "rb") )

# %%
print(fqd_p.relative_loss.to_latex(escape=False))
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrr}
# \toprule
# {} &       h=1 &       h=2 &       h=3 &       h=4 &       h=5 &       h=6 &       h=7 &       h=8 &       h=9 &      h=10 &      h=11 &      h=12 &      h=13 &      h=14 &      h=15 &      h=16 \\
# \midrule
# AR(2)                        &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 &  1.000000 \\
# KNN                          &  0.980626 &  1.058798 &  1.129079 &  1.155546 &  1.135245 &  1.156449 &  1.153801 &  1.207343 &  1.283455 &  1.313793 &  1.379772 &  1.397766 &  1.407345 &  1.382927 &  1.377339 &  1.399675 \\
# DFM                          &  1.077817 &  1.269577 &  1.421374 &  1.306560 &  1.219488 &  1.266283 &  1.421559 &  1.662274 &  1.706987 &  1.900847 &  1.538371 &  1.592498 &  1.401445 &  1.424019 &  1.334756 &  1.411409 \\
# ...

# %%
print(fqd_p.relative_loss.transpose().to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrr}
# \toprule
# {} &  AR(2) &       KNN &       DFM &  Factor EN &  Factor Ridge &  Factor Lasso &  Model average (above models) &    Fat EN &  Fat Ridge &  Fat Lasso &  Factor Random Forests &  Factor Xgboost &  Fat Random Forests &  Fat Xgboost \\
# \midrule
# h=1  &    1.0 &  0.980626 &  1.077817 &   0.978341 &      1.181537 &      0.978830 &                      0.948301 &  0.978341 &   1.181537 &   0.978830 &               1.208871 &        1.287844 &            1.208871 &     1.287844 \\
# h=2  &    1.0 &  1.058798 &  1.269577 &   0.948390 &      1.007078 &      0.948358 &                      0.928202 &  0.948390 &   1.007078 &   0.948358 &               1.112214 &        1.235960 &            1.112214 &     1.235960 \\
# ...

# %%
plt.figure()
fqd_p.horizon_forecasts[0].transpose().plot()
# Out:
# <AxesSubplot:>
